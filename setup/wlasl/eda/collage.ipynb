# %% [markdown]
# ## Imports

# %%
from PIL import Image
import matplotlib.pyplot as plt
from os import listdir
from os.path import isfile, join
import numpy as np

# %%
root_dir = 'images'

# %%
image_dirs = [join(root_dir, f) for f in listdir(root_dir) if isfile(join(root_dir, f))]

# %%
image = image_dirs[0]

# %%
image
# Out:
# 'images/img_00047.jpg'

# %%
x = np.array(Image.open(image))

# %%
images = np.zeros((24, 256, 256, 3))

# %%
images[0].shape
# Out:
# (256, 256, 3)

# %%
for i, image_dir in enumerate(image_dirs):
    images[i] = np.array(Image.open(image_dir))

# %%
images[0].shape
# Out:
# (256, 256, 3)

# %% [markdown]
# ## Creating the collage

# %%
collage = np.zeros((256*4, 256*6, 3))

# %%
for i, image in enumerate(images):
    collage[(i//6)*256:(i//6)*256+256, (i//4)*256:(i//4)*256+256] = image

# %%
x = np.vstack([image[0], image[1]])

# %%
x.shape
# Out:
# (512, 3)

# %%
image[0].shape
# Out:
# (256, 3)

# %%
plt.imshow(collage)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
