# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Augmentation Ablation

# %%
df = pd.read_excel('augmentation.xlsx')

# %%
df.head(50)
# Out:
#      training validation              augment  0_top_1  0_top_5  1_top_1  \
# 0       Train       Test             Baseline    13.91    39.35    16.86
# 1       Train       Test               Cutout    13.33    15.38    12.98
# 2       Train       Test                 Flip    13.91    32.54    16.57
# 3       Train       Test  MultiscaleCrop (MS)    40.53    72.19    38.46
# 4       Train       Test                          0.00     1.00     2.00
# 5       Train       Test               Cutmix    11.54    27.22     7.10
# 6       Train       Test                Mixup     9.17    25.44    11.83
# 7       Train       Test          Augmix (AM)    33.73    64.20    29.88
# 8       Train       Test                          0.00     1.00     2.00
# 9       Train       Test          RandAugment    34.32    64.20    31.95
# 10      Train       Test  RandAugment-T (RAT)    41.72    72.19    36.98
# 11      Train       Test                          0.00     1.00     2.00
# 12      Train       Test               RAT-MS    47.93    75.44    48.52
# 13      Train       Test            RAT-MS-AM    50.30    75.74    49.11
# 14      Train       Test                          0.00     1.00     2.00
# 15  Train+Val       Test             MS-Flip*    50.78    78.68    48.84
# 16  Train+Val       Test           RAT-MS-AM*    60.08    85.27    58.91
#
#     1_top_5  2_top_1  2_top_5  mean_top_1  mean_top_5
# 0     37.28    14.50    43.20   15.090000   39.943333
# 1     14.89    13.50    15.48   13.270000   15.250000
# 2     42.31    18.64    44.38   16.373333   39.743333
# 3     71.89    34.91    68.05   37.966667   70.710000
# 4      3.00     4.00     5.00    0.000000    7.000000
# 5     23.96    13.02    29.59   10.553333   26.923333
# 6     27.81     7.69    23.08    9.563333   25.443333
# 7     60.36    34.32    63.91   32.643333   62.823333
# 8      3.00     4.00     5.00    0.000000    7.000000
# 9     59.76    29.59    64.50   31.953333   62.820000
# 10    69.23    47.63    75.15   42.110000   72.190000
# 11     3.00     4.00     5.00    0.000000    7.000000
# 12    73.67    48.22    74.26   48.223333   74.456667
# 13    76.04    47.93    75.44   49.113333   75.740000
# 14     3.00     4.00     5.00    0.000000    7.000000
# 15    76.36    51.16    79.46   50.260000   78.166667
# 16    82.17    58.91    82.95   59.300000   83.463333

# %%
plt.figure(figsize=(10,6), dpi=300)
g = sns.barplot(x='augment',
            y='mean_top_1',
            data=df,
            palette='viridis'
        )
plt.xticks(rotation=90)
plt.xlabel('Data Augment', fontsize=12)
plt.ylabel('Accuracy (%)', fontsize=12)
g.tick_params(axis='y', labelsize=8)
g.tick_params(axis='x', labelsize=8)
g.tick_params(bottom=False)

# %% [markdown]
# ## Model Ablation

# %% [markdown]
# ### WLASL100

# %%
df = pd.read_excel('wlasl100_models.xlsx')
df.head(50)
# Out:
#       WLASL100  Seed-0 Top-1 Accuracy (%)  Seed-0 Top-5 Accuracy (%)  \
# 0          C3D                      50.77                      79.45
# 1          TSN                      44.57                      78.29
# 2          TSM                      55.81                      86.82
# 3        Tanet                      58.91                      82.95
# 4          CSN                      77.91                      93.02
# 5  Timesformer                      62.40                      84.88
# 6      R(2+1)d                      23.26                      12.02
# 7          I3D                      60.77                      60.08
# 8          TPN                      67.44                      88.37
# 9          TIN                      56.98                      85.27
#
#    Seed-1 Top-1 Accuracy (%)  Seed-1 Top-5 Accuracy (%)  \
# 0                      48.45                      79.46
# 1                      47.67                      78.68
# 2                      55.81                      87.60
# 3                      57.36                      87.21
# 4                      79.84                      93.02
# 5                      61.63                      84.11
# 6                      29.46                      68.60
# 7                      60.85                      60.08
# 8                      62.79                      90.70
# 9                      53.10                      82.95
#
#    Seed-2 Top-1 Accuracy (%)  Seed-3 Top-5 Accuracy (%)  Mean Top-1 Accuracy  \
# 0                      49.22                      79.84            49.480000
# 1                      45.61                      77.78            45.950000
# 2                      55.81                      86.05            55.810000
# 3                      60.08                      84.11            58.783333
# 4                      79.84                      93.02            79.196667
# 5                      61.24                      84.11            61.756667
# 6                      30.23                      66.67            27.650000
# 7                      57.93                      57.75            59.850000
# 8                      58.14                      88.37            62.790000
# 9                      37.21                      72.48            49.096667
#
#    Mean Top-5 Accuracy
# 0            79.583333
# 1            78.250000
# 2            86.823333
# 3            84.756667
# 4            93.020000
# 5            84.366667
# 6            49.096667
# 7            59.303333
# 8            89.146667
# 9            80.233333

# %%
plt.figure(figsize=(10,6), dpi=300)
g = sns.barplot(x='WLASL100',
            y='Mean Top-1 Accuracy',
            data=df,
            palette='viridis',
            order=df.sort_values('Mean Top-1 Accuracy').WLASL100,
        )
# plt.xticks(rotation=90)
plt.xlabel('Model', fontsize=12)
plt.ylabel('Accuracy (%)', fontsize=12)
g.tick_params(axis='y', labelsize=8)
g.tick_params(axis='x', labelsize=8)
g.tick_params(bottom=False)

# %% [markdown]
# ### AUTSL

# %%
df = pd.read_excel('autsl_models.xlsx')
df.head(50)
# Out:
#          AUTSL  Seed-0 Top-1 Accuracy (%)  Seed-0 Top-5 Accuracy (%)  \
# 0          CSN                      90.25                      98.72
# 1  Timesformer                      76.58                      93.45
# 2          TPN                      89.82                      98.93
#
#    Seed-1 Top-1 Accuracy (%)  Seed-1 Top-5 Accuracy (%)  \
# 0                      93.32                      99.36
# 1                      70.22                      90.99
# 2                      89.23                      98.34
#
#    Seed-2 Top-1 Accuracy (%)  Seed-3 Top-5 Accuracy (%)  Mean Top-1 Accuracy  \
# 0                      89.01                      98.72            90.860000
# 1                      72.84                      92.68            73.213333
# 2                      89.54                      98.56            89.530000
#
#    Mean Top-5 Accuracy
# 0            98.933333
# 1            92.373333
# 2            98.610000

# %%
df.plot(x='AUTSL',
        y=['Mean Top-1 Accuracy', 'Mean Top-5 Accuracy'],
#         palette='viridis',
        kind='bar'
       )
plt.xlabel('Model', fontsize=12)
plt.ylabel('Accuracy (%)', fontsize=12)
plt.viridis()

# %%
plt.figure(figsize=(10,6), dpi=300)
g = sns.barplot(x='AUTSL',
            y=['Mean Top-1 Accuracy', 'Mean Top-1 Accuracy'],
            data=df,
            palette='viridis',
        )
# plt.xticks(rotation=90)
plt.xlabel('Model', fontsize=12)
plt.ylabel('Accuracy (%)', fontsize=12)
g.tick_params(axis='y', labelsize=8)
g.tick_params(axis='x', labelsize=8)
g.tick_params(bottom=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [68], line 2
#       1 plt.figure(figsize=(10,6), dpi=300)
# ----> 2 g = sns.barplot(x='AUTSL',
#       3             y=['Mean Top-1 Accuracy', 'Mean Top-1 Accuracy'],
#       4             data=df,
#       5             palette='viridis',
#       6         )
#       7 # plt.xticks(rotation=90)
#       8 plt.xlabel('Model', fontsize=12)
#
# File ~/miniconda3/envs/wlasl/lib/python3.8/site-packages/seaborn/categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
#    2760 if ax is None:
#    2761     ax = plt.gca()
#
# File ~/miniconda3/envs/wlasl/lib/python3.8/site-packages/seaborn/categorical.py:1530, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1525 def __init__(self, x, y, hue, data, order, hue_order,
#    1526              estimator, errorbar, n_boot, units, seed,
#    1527              orient, color, palette, saturation, width,
#    1528              errcolor, errwidth, capsize, dodge):
#    1529     """Initialize the plotter."""
# -> 1530     self.establish_variables(x, y, hue, data, orient,
#    1531                              order, hue_order, units)
#    1532     self.establish_colors(color, palette, saturation)
#    1533     self.estimate_statistic(estimator, errorbar, n_boot, seed)
#
# File ~/miniconda3/envs/wlasl/lib/python3.8/site-packages/seaborn/categorical.py:544, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     541         raise ValueError(err)
#     543 # Figure out the plotting orientation
# --> 544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#     548 # Option 2a:
#     549 # We are plotting a single set of data
#     550 # ------------------------------------
#     551 if x is None or y is None:
#     552
#     553     # Determine where the data are
#
# File ~/miniconda3/envs/wlasl/lib/python3.8/site-packages/seaborn/_oldcore.py:1585, in infer_orient(x, y, orient, require_numeric)
#    1557 """Determine how the plot should be oriented based on the data.
#    1558
#    1559 For historical reasons, the convention is to call a plot "horizontally"
#    (...)
#    1581
#    1582 """
#    1584 x_type = None if x is None else variable_type(x)
# -> 1585 y_type = None if y is None else variable_type(y)
#    1587 nonnumeric_dv_error = "{} orientation requires numeric `{}` variable."
#    1588 single_var_warning = "{} orientation ignored with only `{}` specified."
#
# File ~/miniconda3/envs/wlasl/lib/python3.8/site-packages/seaborn/_oldcore.py:1502, in variable_type(vector, boolean_type)
#    1499     return VariableType("categorical")
#    1501 # Special-case all-na data, which is always "numeric"
# -> 1502 if pd.isna(vector).all():
#    1503     return VariableType("numeric")
#    1505 # Special-case binary/boolean data, allow caller to determine
#    1506 # This triggers a numpy warning when vector has strings/objects
#    1507 # https://github.com/numpy/numpy/issues/6784
#    (...)
#    1511 # https://github.com/numpy/numpy/issues/13548
#    1512 # This is considered a bug by numpy and will likely go away.
#
# File ~/miniconda3/envs/wlasl/lib/python3.8/site-packages/pandas/core/generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# ### WLASL2000

# %%
df = pd.read_excel('wlasl2000_models.xlsx')
df.head(50)
# Out:
#   WLASL2000  Seed-0 Top-1 Accuracy (%)  Seed-0 Top-5 Accuracy (%)  \
# 0       TPN                      30.64                      65.72
# 1       CSN                      38.87                      71.48
#
#    Seed-1 Top-1 Accuracy (%)  Seed-1 Top-5 Accuracy (%)  \
# 0                      28.45                      62.28
# 1                      44.04                      77.28
#
#    Seed-2 Top-1 Accuracy (%)  Seed-3 Top-5 Accuracy (%)  Mean Top-1 Accuracy  \
# 0                      26.75                      59.22            28.613333
# 1                      46.02                      77.26            42.976667
#
#    Mean Top-5 Accuracy
# 0            62.406667
# 1            75.340000

# %%
plt.figure(figsize=(10,6), dpi=300)
g = sns.barplot(x='WLASL2000',
            y='Mean Top-1 Accuracy',
            data=df,
            palette='viridis',
            order=df.sort_values('Mean Top-1 Accuracy').WLASL2000,
        )
# plt.xticks(rotation=90)
plt.xlabel('Model', fontsize=12)
plt.ylabel('Accuracy (%)', fontsize=12)
g.tick_params(axis='y', labelsize=8)
g.tick_params(axis='x', labelsize=8)
g.tick_params(bottom=False)
